# %% [markdown]
#  # dictionary creation techniques

# %%
s = list("abcdef")
d3 = dict.fromkeys(s,0)
print(d3)
# Out:
# {'a': 0, 'b': 0, 'c': 0, 'd': 0, 'e': 0, 'f': 0}

# %%
countries =[ ('th' , 'thailand') ,('jp' , 'japan') ]
d4 = dict(countries)
print(d4)
# Out:
# {'th': 'thailand', 'jp': 'japan'}

# %%
s = list("abcdef")
z = list("becadt")
d3 = dict(zip(s,z))
print(d3)
# Out:
# {'a': 'b', 'b': 'e', 'c': 'c', 'd': 'a', 'e': 'd', 'f': 't'}
